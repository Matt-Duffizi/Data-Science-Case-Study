# %% [markdown]
# ## Model Complete

# %%
# Libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from imblearn.over_sampling import SMOTE

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
from sklearn.preprocessing import FunctionTransformer

# %%
# Load Data
train = pd.read_csv('Train.csv')
test = pd.read_csv('Test.csv')

# %%
train['country'].value_counts()[-110:-90]
# Out:
# DENMARK           178
# NORWAY            151
# RWANDA            145
# JAPAN             137
# AUSTRIA           124
# IRELAND           122
# OMAN               92
# POLAND             84
# DRC                82
# NEW ZEALAND        82
# ISRAEL             75
# KOREA              66
# RUSSIA             64
# FINLAND            62
# MALAYSIA           61
# CONGO              58
# MALAWI             46
# PORTUGAL           46
# BRAZIL             43
# CZECH REPUBLIC     40
# Name: country, dtype: int64

# %%
# Columns
columns = list(test.columns)

bool_columns = columns[10:17]
bool_columns.append("first_trip_tz")

num_features = [ 'total_female', 'total_male', 'night_mainland','night_zanzibar']

cat_features = ['country','age_group','travel_with','purpose',
              'main_activity','info_source','tour_arrangement']

target = 'cost_category'

scoring= 'f1_weighted'

# %%
# FUNCTIONS

def dropId(df):
    df.drop('Tour_ID',axis=1, inplace =True)
    return df

def fillNa(df):
    df['travel_with'].fillna(df['travel_with'].value_counts().index[0],inplace =True)
    df['total_male'].fillna(round(df['total_male'].mean()),inplace =True)
    df['total_female'].fillna(round(df['total_female'].mean()),inplace =True)
    return df
    
def boolConverter(df):
    bool_columns_list = bool_columns
    for col in bool_columns_list:
        df[col] = df[col].apply(lambda x: 1 if x == "Yes" else 0)
    return df

def categoricalFeatureReductor(df):
    for col in df.columns:
        if df[col].dtype == "object":
            counts = df[col].value_counts()
            value_below = counts[counts<50]
            df[col] = df[col].apply(lambda x: "Other" if x in list(value_below.index) else x)
    return df

def outliersReductor(df):
    for col in num_features:
        q_2 = df[col].quantile(0.25)
        q_3 = df[col].quantile(0.75)
        IQR =  q_3 - q_2
        outlier = q_3+IQR*1.5
        df[col] = df[col].apply(lambda x: outlier if x > outlier else x)
    return df

def categoricalConverter(df):
    cat_list = cat_features
    df[cat_list] = df[cat_list].astype('category')
    return df

def oneHot(df):
    cat_list = cat_features
    df_new = pd.get_dummies(df,columns=cat_list)
    return df_new
    
def targetConverter(df):
    if target in df.columns:
        df[target] = df[target].astype('category')
        print(dict(enumerate(df['cost_category'].cat.categories)))
        df['cost_category'] = df['cost_category'].cat.codes
    return df
    
def floatizator(df):
    df = df.astype('float64')
    if target in df.columns:
    	df[target] = df[target].astype('category')
    return df
    
def X_y_generator_and_ovesampling(df):
    X = df.drop(target,axis=1)
    y = df[target]
    class_dic = {5.0:6000,4.0:6000,3.0:6000,2.0:6000,1.0:6000,0.0:6000}
    smote = SMOTE(sampling_strategy=class_dic, random_state= 42)
    X_rebalanced, y_rebalanced = smote.fit_resample(X,y)
    return X_rebalanced,y_rebalanced

# %%
# PREPROCESSING
def preprocessing(df):
    p = df.copy()
    if len(p.columns) == len(columns) or len(p.columns) == len(columns)+1 :
        p = dropId(p)
        p = fillNa(p)
        p = boolConverter(p)
        p = categoricalFeatureReductor(p)
        p = outliersReductor(p)
        p = categoricalConverter(p)
        p = oneHot(p)
        p = targetConverter(p)
        p = floatizator(p)
        
    return p

def colChecker(df):
    if len(df.columns) != 87:
        num = 87 - len(df.columns)
        for i in range(num):
            df[f'{i}'] = 0.5
    return df

p = preprocessing(train)
X,y =X_y_generator_and_ovesampling(p)
print(X.shape)
print(X.info())

X.drop(['country_CONGO','country_MALAYSIA','country_FINLAND','country_RUSSIA','country_KOREA','country_ISRAEL',
            'country_DRC','country_NEW ZEALAND','country_POLAND','country_OMAN','country_IRELAND','country_AUSTRIA',
        	'country_JAPAN','country_RWANDA','country_NORWAY'] ,axis=1,inplace= True)

print(X.shape)

# Just in case I need some partition for testing
X_train,X_test, y_train, y_test  = train_test_split(X,y,random_state = 42, test_size= 0.2, stratify=y)

scaler = MinMaxScaler()
X_std = scaler.fit_transform(X)
df_train = pd.DataFrame(X_std)
# Out:
# {0: 'High Cost', 1: 'Higher Cost', 2: 'Highest Cost', 3: 'Low Cost', 4: 'Lower Cost', 5: 'Normal Cost'}
# (36000, 87)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36000 entries, 0 to 35999
# Data columns (total 87 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   total_female                                 36000 non-null  float64
#  1   total_male                                   36000 non-null  float64
#  2   package_transport_int                        36000 non-null  float64
#  3   package_accomodation                         36000 non-null  float64
#  4   package_food                                 36000 non-null  float64
#  5   package_transport_tz                         36000 non-null  float64
#  6   package_sightseeing                          36000 non-null  float64
#  7   package_guided_tour                          36000 non-null  float64
#  8   package_insurance                            36000 non-null  float64
#  9   night_mainland                               36000 non-null  float64
#  10  night_zanzibar                               36000 non-null  float64
#  11  first_trip_tz                                36000 non-null  float64
#  12  country_AUSTRALIA                            36000 non-null  float64
#  13  country_AUSTRIA                              36000 non-null  float64
#  14  country_BELGIUM                              36000 non-null  float64
#  15  country_BURUNDI                              36000 non-null  float64
#  16  country_CANADA                               36000 non-null  float64
#  17  country_CHINA                                36000 non-null  float64
#  18  country_CONGO                                36000 non-null  float64
#  19  country_DENMARK                              36000 non-null  float64
#  20  country_DRC                                  36000 non-null  float64
#  21  country_FINLAND                              36000 non-null  float64
#  22  country_FRANCE                               36000 non-null  float64
#  23  country_GERMANY                              36000 non-null  float64
#  24  country_INDIA                                36000 non-null  float64
#  25  country_IRELAND                              36000 non-null  float64
#  26  country_ISRAEL                               36000 non-null  float64
#  27  country_ITALY                                36000 non-null  float64
#  28  country_JAPAN                                36000 non-null  float64
#  29  country_KENYA                                36000 non-null  float64
#  30  country_KOREA                                36000 non-null  float64
#  31  country_MALAYSIA                             36000 non-null  float64
#  32  country_NETHERLANDS                          36000 non-null  float64
#  33  country_NEW ZEALAND                          36000 non-null  float64
#  34  country_NORWAY                               36000 non-null  float64
#  35  country_OMAN                                 36000 non-null  float64
#  36  country_Other                                36000 non-null  float64
#  37  country_POLAND                               36000 non-null  float64
#  38  country_RUSSIA                               36000 non-null  float64
#  39  country_RWANDA                               36000 non-null  float64
#  40  country_SOUTH AFRICA                         36000 non-null  float64
#  41  country_SPAIN                                36000 non-null  float64
#  42  country_SWEDEN                               36000 non-null  float64
#  43  country_SWIZERLAND                           36000 non-null  float64
#  44  country_UAE                                  36000 non-null  float64
#  45  country_UGANDA                               36000 non-null  float64
#  46  country_UNITED KINGDOM                       36000 non-null  float64
#  47  country_UNITED STATES OF AMERICA             36000 non-null  float64
#  48  country_ZAMBIA                               36000 non-null  float64
#  49  country_ZIMBABWE                             36000 non-null  float64
#  50  age_group_18-24                              36000 non-null  float64
#  51  age_group_25-44                              36000 non-null  float64
#  52  age_group_45-64                              36000 non-null  float64
#  53  age_group_65+                                36000 non-null  float64
#  54  age_group_<18                                36000 non-null  float64
#  55  travel_with_Alone                            36000 non-null  float64
#  56  travel_with_With Children                    36000 non-null  float64
#  57  travel_with_With Other Friends/Relatives     36000 non-null  float64
#  58  travel_with_With Spouse                      36000 non-null  float64
#  59  travel_with_With Spouse and Children         36000 non-null  float64
#  60  purpose_Business                             36000 non-null  float64
#  61  purpose_Leisure and Holidays                 36000 non-null  float64
#  62  purpose_Meetings and Conference              36000 non-null  float64
#  63  purpose_Other                                36000 non-null  float64
#  64  purpose_Scientific and Academic              36000 non-null  float64
#  65  purpose_Visiting Friends and Relatives       36000 non-null  float64
#  66  purpose_Volunteering                         36000 non-null  float64
#  67  main_activity_Beach Tourism                  36000 non-null  float64
#  68  main_activity_Bird Tourism                   36000 non-null  float64
#  69  main_activity_Business                       36000 non-null  float64
#  70  main_activity_Conference Tourism             36000 non-null  float64
#  71  main_activity_Cultural Tourism               36000 non-null  float64
#  72  main_activity_Hunting Tourism                36000 non-null  float64
#  73  main_activity_Mountain Climbing              36000 non-null  float64
#  74  main_activity_Other                          36000 non-null  float64
#  75  main_activity_Widlife Tourism                36000 non-null  float64
#  76  main_activity_Wildlife Tourism               36000 non-null  float64
#  77  info_source_Friends, relatives               36000 non-null  float64
#  78  info_source_Inflight magazines               36000 non-null  float64
#  79  info_source_Newspaper, magazines, brochures  36000 non-null  float64
#  80  info_source_Others                           36000 non-null  float64
#  81  info_source_Radio, TV, Web                   36000 non-null  float64
#  82  info_source_Tanzania Mission Abroad          36000 non-null  float64
#  83  info_source_Trade fair                       36000 non-null  float64
#  84  info_source_Travel agent, tour operator      36000 non-null  float64
#  85  tour_arrangement_Independent                 36000 non-null  float64
#  86  tour_arrangement_Package Tour                36000 non-null  float64
# dtypes: float64(87)
# memory usage: 23.9 MB
# None
# (36000, 72)

# %%
# MODEL PARAMS
# Random Forest tuning
parameters ={"max_depth": [6, None],
             "max_features": [10, 'sqrt'],
             "min_samples_split": [2,3],
            "n_estimators": [100],
             "ccp_alpha" : [0,0.005]}

rfc = RandomForestClassifier(random_state=42) 

rs_cv = RandomizedSearchCV(rfc,param_distributions=parameters, 
                           n_iter=10, scoring=scoring, cv = 10,random_state=42) 

rs_cv.fit(X_std,y)

print("RandomSearch:", rs_cv.best_params_)
print("Score CV:", rs_cv.best_score_, "\n\n")
# Out:
# RandomSearch: {'n_estimators': 100, 'min_samples_split': 3, 'max_features': 10, 'max_depth': None, 'ccp_alpha': 0}
# Score CV: 0.7465263671819578

# %%
# Saving Results
model = rs_cv.best_estimator_
mod_temp = RandomForestClassifier(random_state=42) 
mod_temp_2 = RandomForestClassifier(random_state=10) 

#transformer
transformer = FunctionTransformer(preprocessing)
transformer2 = FunctionTransformer(colChecker)
scaler = MinMaxScaler()

pipe = Pipeline([('transformer', transformer),
                 ("scaler", scaler),
                 ('model', model)
                ])

pipe.fit(df_train, y)
# Out:
# Pipeline(steps=[('transformer',
#                  FunctionTransformer(func=<function preprocessing at 0x7fbdde2fbe50>)),
#                 ('scaler', MinMaxScaler()),
#                 ('model',
#                  RandomForestClassifier(ccp_alpha=0, max_features=10,
#                                         min_samples_split=3,
#                                         random_state=42))])

# %%
# saving pipe
from joblib import dump


dump(pipe, 'RandomForestModel_Matteo.joblib')
# Out:
# ['RandomForestModel_Matteo.joblib']

# %%
#Prediction of the test
pred = pipe.predict(test)
print(pred[:200])
# Out:
# [5. 1. 1. 5. 0. 5. 1. 5. 1. 5. 5. 0. 1. 5. 1. 5. 1. 5. 1. 5. 5. 5. 5. 1.
#  5. 5. 1. 5. 5. 5. 5. 1. 5. 5. 1. 1. 1. 1. 5. 1. 5. 1. 1. 1. 1. 1. 1. 0.
#  0. 5. 1. 1. 1. 5. 0. 1. 1. 5. 1. 1. 1. 0. 1. 5. 1. 1. 0. 1. 1. 1. 5. 1.
#  5. 0. 5. 5. 1. 5. 5. 5. 1. 1. 5. 0. 1. 1. 5. 1. 5. 1. 5. 5. 5. 1. 1. 1.
#  1. 5. 1. 1. 1. 5. 5. 5. 1. 1. 5. 4. 5. 1. 5. 5. 5. 1. 1. 1. 1. 5. 1. 5.
#  1. 5. 1. 5. 1. 1. 5. 1. 1. 1. 1. 5. 1. 5. 1. 1. 1. 5. 1. 5. 1. 1. 1. 1.
#  5. 1. 1. 2. 5. 5. 1. 5. 1. 5. 1. 1. 5. 1. 1. 1. 5. 1. 1. 5. 5. 1. 5. 1.
#  5. 1. 1. 5. 1. 1. 1. 1. 5. 1. 1. 1. 5. 1. 1. 5. 1. 1. 5. 1. 5. 1. 1. 4.
#  1. 5. 5. 5. 1. 1. 5. 5.]

# %%
final_prediction = pd.DataFrame(test['Tour_ID'])
final_prediction['prediction'] = pred
final_prediction['prediction'] = final_prediction['prediction'].map({0: 'High Cost', 1: 'Higher Cost', 2: 'Highest Cost', 3: 'Low Cost', 4: 'Lower Cost', 5: 'Normal Cost'})

# %%
final_prediction.tail(20)
# Out:
#               Tour_ID   prediction
# 6149  tour_idl39b6q02  Normal Cost
# 6150  tour_idwhu9n1vb  Normal Cost
# 6151  tour_id2g7h25oe  Higher Cost
# 6152  tour_idb8zzhsz6  Higher Cost
# 6153  tour_ide2uj3gqh  Higher Cost
# 6154  tour_idv4rpovrd  Normal Cost
# 6155  tour_id6zyaxxy3  Normal Cost
# 6156  tour_idf4uv3kyc  Higher Cost
# 6157  tour_idxtxvnrki  Normal Cost
# 6158  tour_id2zlugaki  Normal Cost
# 6159  tour_idwyrdca85  Higher Cost
# 6160  tour_idfz54zy6l  Higher Cost
# 6161  tour_idlefwawyr  Higher Cost
# 6162  tour_idpw5a3udz  Normal Cost
# 6163  tour_ido3jj5782  Higher Cost
# 6164  tour_id2deyfjhq    High Cost
# 6165  tour_idlenv2rio  Normal Cost
# 6166  tour_id7wwqrs0p    High Cost
# 6167  tour_idx80vbw5a  Normal Cost
# 6168  tour_id8fkkwytb  Normal Cost

# %%
test[['Tour_ID','country']].tail(20)
# Out:
#               Tour_ID                   country
# 6149  tour_idl39b6q02                     KENYA
# 6150  tour_idwhu9n1vb            UNITED KINGDOM
# 6151  tour_id2g7h25oe            UNITED KINGDOM
# 6152  tour_idb8zzhsz6                     ITALY
# 6153  tour_ide2uj3gqh            UNITED KINGDOM
# 6154  tour_idv4rpovrd                     KENYA
# 6155  tour_id6zyaxxy3              SOUTH AFRICA
# 6156  tour_idf4uv3kyc  UNITED STATES OF AMERICA
# 6157  tour_idxtxvnrki                  ZIMBABWE
# 6158  tour_id2zlugaki                  ZIMBABWE
# 6159  tour_idwyrdca85                     ITALY
# 6160  tour_idfz54zy6l            UNITED KINGDOM
# 6161  tour_idlefwawyr                 AUSTRALIA
# 6162  tour_idpw5a3udz                    UGANDA
# 6163  tour_ido3jj5782                    CANADA
# 6164  tour_id2deyfjhq                  ZIMBABWE
# 6165  tour_idlenv2rio                       DRC
# 6166  tour_id7wwqrs0p                    CANADA
# 6167  tour_idx80vbw5a                    CANADA
# 6168  tour_id8fkkwytb                     KENYA

# %%
final_prediction.to_csv( 'final_submission.csv' ,index=False,sep=";")
